# %% [markdown]
# <a href="https://colab.research.google.com/github/Bonifucksy/bigdatalearning/blob/master/h/w4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = pd.read_excel('ad_campaigns.xlsx')
data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
data.head(10)
# Out:
#       название_группы  ...                                             ссылка
# 0   мрт менделеевская  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1             мрт цао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 2             мрт цао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 3             мрт цао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 4             мрт сао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 5             мрт сао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 6             мрт сао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 7  мрт в москве в сао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 8  мрт в москве в сао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 9  мрт в москве в сао  ...  https://awesome-site.ru/?utm_source=yandex&utm...
#
# [10 rows x 7 columns]

# %%
df = data[data['продуктивность'] == data.groupby('название_группы')['продуктивность'].transform('min')]

# %%
df.sort_values(by=['название_группы', 'продуктивность'], ascending=[True, True]).head(50)
# Out:
#                         название_группы  ...                                             ссылка
# 1590               1 5 москва мрт тесла  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 350                      1 градская мрт  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1592                  1 мрт нагатинский  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1593                  1 мрт нагатинский  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1595                     1 мрт парковый  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1597               1 мрт парковый улица  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1601         1 парковый томография цена  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 2158                      10 мрт палиха  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1603        11 мрт сокольники стромынка  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# ...

# %%
df = df.sort_values('продуктивность').drop_duplicates('название_группы')

# %%
df.sort_values(by=['название_группы', 'продуктивность'], ascending=[True, True]).head(50)
# Out:
#                         название_группы  ...                                             ссылка
# 1590               1 5 москва мрт тесла  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 350                      1 градская мрт  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1592                  1 мрт нагатинский  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1595                     1 мрт парковый  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1597               1 мрт парковый улица  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1601         1 парковый томография цена  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 2158                      10 мрт палиха  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 1603        11 мрт сокольники стромынка  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# 2147                   11 мрт стромынка  ...  https://awesome-site.ru/?utm_source=yandex&utm...
# ...

# %%
df.sort_values(by=['название_группы', 'продуктивность'], ascending=[True, True]).hist(['продуктивность'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2dd5dd04a8>]],
#       dtype=object)
